# %% [markdown]
# ## Resumo do notebook
#
# Nesse notebook preparamos a limpeza do catalogo e preparação dos esquemas para uso de dados em nuvem.

# %%
# %sql
DROP CATALOG IF EXISTS ons CASCADE;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ons;
USE CATALOG ons;

# %%
# %sql
DROP SCHEMA IF EXISTS staging CASCADE;
DROP SCHEMA IF EXISTS dados CASCADE;

# %%
# %sql
CREATE SCHEMA staging;
CREATE SCHEMA dados;
