# %%
from pyspark.sql import functions as F

df = spark.table("ons.dados.capacidade_geracao")

# Análise descritiva
display(df.describe())

# Contagem de nulos por coluna
display(
  df.select([
    F.count(
      F.when(
        F.col(c).isNull(),
        c
      )
    ).alias(c)
    for c in df.columns
  ])
)

# Análise de tipos de dados
display(df.dtypes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>id_subsistema</th><th>nom_subsistema</th><th>id_estado</th><th>nom_estado</th><th>nom_modalidadeoperacao</th><th>nom_agenteproprietario</th><th>nom_agenteoperador</th><th>nom_tipousina</th><th>nom_usina</th><th>ceg</th><th>nom_unidadegeradora</th><th>cod_equipamento</th><th>num_unidadegeradora</th><th>nom_combustivel</th><th>val_potenciaefetiva</th></tr></thead><tbody><tr><td>count</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td><td>5450</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>14.488303130148271</td><td>null</td><td>36.99127207218156</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>159.58473667269342</td><td>null</td><td>81.4896430664635</td></tr><tr><td>min</td><td>N</td><td>NORDESTE</td><td>AC</td><td>ACRE</td><td>TIPO I</td><td>ABENGOA</td><td>ABENGOA</td><td>EOLIELÉTRICA</td><td>14 DE JULHO</td><td>EOL.CV.BA.030283-0.01</td><td>UG    1 MW PIE-RP                    2 SP</td><td>ACBJ--0UG1          </td><td>01    </td><td>BIOMASSA</td><td>0.325</td></tr><tr><td>max</td><td>SE</td><td>SUL</td><td>TO</td><td>TOCANTINS</td><td>TIPO II-C</td><td>ZEUS II</td><td>XAVANTES</td><td>TÉRMICA</td><td>ÁGUA VERMELHA VII</td><td>UTN.UR.RJ.000101-5.01</td><td>UG 9P87 MW AC_XVII                  R3 MG</td><td>TOUHSA0UG2          </td><td>XXXX  </td><td>ÓLEO DIESEL</td><td>1350.0</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_subsistema</th><th>nom_subsistema</th><th>id_estado</th><th>nom_estado</th><th>nom_modalidadeoperacao</th><th>nom_agenteproprietario</th><th>nom_agenteoperador</th><th>nom_tipousina</th><th>nom_usina</th><th>ceg</th><th>nom_unidadegeradora</th><th>cod_equipamento</th><th>num_unidadegeradora</th><th>nom_combustivel</th><th>dat_entradateste</th><th>dat_entradaoperacao</th><th>dat_desativacao</th><th>val_potenciaefetiva</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>7</td><td>0</td><td>4484</td><td>0</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>id_subsistema</td><td>string</td></tr><tr><td>nom_subsistema</td><td>string</td></tr><tr><td>id_estado</td><td>string</td></tr><tr><td>nom_estado</td><td>string</td></tr><tr><td>nom_modalidadeoperacao</td><td>string</td></tr><tr><td>nom_agenteproprietario</td><td>string</td></tr><tr><td>nom_agenteoperador</td><td>string</td></tr><tr><td>nom_tipousina</td><td>string</td></tr><tr><td>nom_usina</td><td>string</td></tr><tr><td>ceg</td><td>string</td></tr><tr><td>nom_unidadegeradora</td><td>string</td></tr><tr><td>cod_equipamento</td><td>string</td></tr><tr><td>num_unidadegeradora</td><td>string</td></tr><tr><td>nom_combustivel</td><td>string</td></tr><tr><td>dat_entradateste</td><td>timestamp</td></tr><tr><td>dat_entradaoperacao</td><td>timestamp</td></tr><tr><td>dat_desativacao</td><td>timestamp</td></tr><tr><td>val_potenciaefetiva</td><td>double</td></tr></tbody></table></div>
